# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=sns.load_dataset('tips')
X=df[['total_bill']]
y=df[['tip']]

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X)

# %%
mse=mean_squared_error(y,y_pred)
r2=r2_score(y,y_pred)
mse,r2
# Out:
# (1.036019442011377, 0.45661658635167657)

# %%
new_X=np.array([25,15.5,17,26.1]).reshape(-1,1)
predicted_y=model.predict(new_X)
predicted_y
# Out:
# C:\Users\goatt\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.54588255],
#        [2.54814963],
#        [2.70568641],
#        [3.66140952]])

# %%
plt.scatter(X,y,color="blue")
plt.plot(X,y_pred,c="r")
plt.scatter(new_X,predicted_y,c="g")
plt.grid(True)
